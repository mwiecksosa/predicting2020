# %%
#Author: Naina Balepur
#nainab2@illinois.edu
#This file takes 1all_allStates_tweets.csv and labels users with gender and race 
#according to condensed_lastnames.csv and condensed_firstnames.csv

# %%
import pandas
import numpy as np

df = pandas.read_csv('1allStates_tweets.csv', encoding='utf8', engine='python')
df
# Out:
#         Unnamed: 0                   id      conversation_id    created_at  \
# 0                0  1323308238167822338  1323069815880327173  1.604336e+12
# 1                1  1323014312139640833  1323014312139640833  1.604266e+12
# 2                2  1321831269991407618  1321810507414818821  1.603984e+12
# 3                3  1321830002590179329  1321830002590179329  1.603984e+12
# 4                4  1321629643863150592  1321577509704601601  1.603936e+12
# ...            ...                  ...                  ...           ...
# 247830          23  1285911223037501440  1285911223037501440  1.595420e+12
# 247831          24  1285910798548770818  1285910798548770818  1.595420e+12
# 247832          25  1285758027803623424  1285758027803623424  1.595384e+12
# 247833          26  1285755913706577925  1285755913706577925  1.595383e+12
# 247834          27  1252644543251415041  1250984356023357440  1.587489e+12
#
#                        date  timezone place  \
# 0       2020-11-02 08:57:24      -800   NaN
# 1       2020-11-01 13:29:27      -800   NaN
# 2       2020-10-29 08:08:27      -800   NaN
# 3       2020-10-29 08:03:25      -800   NaN
# 4       2020-10-28 18:47:16      -800   NaN
# ...                     ...       ...   ...
# 247830  2020-07-22 05:15:01      -800   NaN
# 247831  2020-07-22 05:13:20      -800   NaN
# 247832  2020-07-21 19:06:16      -800   NaN
# 247833  2020-07-21 18:57:52      -800   NaN
# 247834  2020-04-21 10:05:06      -800   NaN
#
#                                                     tweet language  \
# 0       @JoeBiden So you are not taking back the tax b...       en
# 1       Two more days of campaigning ads and covid sca...       en
# 2       @nashvegas__ Everyone will be paying higher ta...       en
# 3       I swear this man has been reading my mind for ...       en
# 4       @TuckerCarlson Joe Biden is not a career polit...       en
# ...                                                   ...      ...
# 247830  Trump genocide he's killing people all over Am...       en
# 247831  Trump has killed 140000 people can't change th...       en
# 247832  No one is trying harder than Kemp to kill peop...       en
# 247833  They are killing kids at border daily Trump is...       en
# 247834  @baxterpm If it means getting a dig in at trum...       en
#
#                        hashtags  ... geo  source  user_rt_id user_rt  \
# 0       ['bidenliesabouttaxes']  ... NaN     NaN         NaN     NaN
# 1                            []  ... NaN     NaN         NaN     NaN
# 2                            []  ... NaN     NaN         NaN     NaN
# 3                            []  ... NaN     NaN         NaN     NaN
# 4                            []  ... NaN     NaN         NaN     NaN
# ...                         ...  ...  ..     ...         ...     ...
# 247830                       []  ... NaN     NaN         NaN     NaN
# 247831                       []  ... NaN     NaN         NaN     NaN
# 247832                       []  ... NaN     NaN         NaN     NaN
# 247833                       []  ... NaN     NaN         NaN     NaN
# 247834                       []  ... NaN     NaN         NaN     NaN
#
#        retweet_id                                           reply_to  \
# 0             NaN  [{'screen_name': 'JoeBiden', 'name': 'Joe Bide...
# 1             NaN                                                 []
# 2             NaN  [{'screen_name': 'nashvegas__', 'name': 'Nash'...
# 3             NaN                                                 []
# 4             NaN  [{'screen_name': 'TuckerCarlson', 'name': 'Tuc...
# ...           ...                                                ...
# 247830        NaN                                                 []
# 247831        NaN                                                 []
# 247832        NaN                                                 []
# 247833        NaN                                                 []
# 247834        NaN  [{'screen_name': 'baxterpm', 'name': 'Paul Bax...
#
#         retweet_date translate trans_src trans_dest
# 0                NaN       NaN       NaN        NaN
# 1                NaN       NaN       NaN        NaN
# 2                NaN       NaN       NaN        NaN
# 3                NaN       NaN       NaN        NaN
# 4                NaN       NaN       NaN        NaN
# ...              ...       ...       ...        ...
# 247830           NaN       NaN       NaN        NaN
# 247831           NaN       NaN       NaN        NaN
# 247832           NaN       NaN       NaN        NaN
# 247833           NaN       NaN       NaN        NaN
# 247834           NaN       NaN       NaN        NaN
#
# [247835 rows x 39 columns]

# %%
new = df["name"].str.split(" ", expand = True)

df["user_fn"]= new[0] 
df["user_ln"]= new[1] 

df
# Out:
#         Unnamed: 0                   id      conversation_id    created_at  \
# 0                0  1323308238167822338  1323069815880327173  1.604336e+12
# 1                1  1323014312139640833  1323014312139640833  1.604266e+12
# 2                2  1321831269991407618  1321810507414818821  1.603984e+12
# 3                3  1321830002590179329  1321830002590179329  1.603984e+12
# 4                4  1321629643863150592  1321577509704601601  1.603936e+12
# ...            ...                  ...                  ...           ...
# 247830          23  1285911223037501440  1285911223037501440  1.595420e+12
# 247831          24  1285910798548770818  1285910798548770818  1.595420e+12
# 247832          25  1285758027803623424  1285758027803623424  1.595384e+12
# 247833          26  1285755913706577925  1285755913706577925  1.595383e+12
# 247834          27  1252644543251415041  1250984356023357440  1.587489e+12
#
#                        date  timezone place  \
# 0       2020-11-02 08:57:24      -800   NaN
# 1       2020-11-01 13:29:27      -800   NaN
# 2       2020-10-29 08:08:27      -800   NaN
# 3       2020-10-29 08:03:25      -800   NaN
# 4       2020-10-28 18:47:16      -800   NaN
# ...                     ...       ...   ...
# 247830  2020-07-22 05:15:01      -800   NaN
# 247831  2020-07-22 05:13:20      -800   NaN
# 247832  2020-07-21 19:06:16      -800   NaN
# 247833  2020-07-21 18:57:52      -800   NaN
# 247834  2020-04-21 10:05:06      -800   NaN
#
#                                                     tweet language  \
# 0       @JoeBiden So you are not taking back the tax b...       en
# 1       Two more days of campaigning ads and covid sca...       en
# 2       @nashvegas__ Everyone will be paying higher ta...       en
# 3       I swear this man has been reading my mind for ...       en
# 4       @TuckerCarlson Joe Biden is not a career polit...       en
# ...                                                   ...      ...
# 247830  Trump genocide he's killing people all over Am...       en
# 247831  Trump has killed 140000 people can't change th...       en
# 247832  No one is trying harder than Kemp to kill peop...       en
# 247833  They are killing kids at border daily Trump is...       en
# 247834  @baxterpm If it means getting a dig in at trum...       en
#
#                        hashtags  ... user_rt_id  user_rt  retweet_id  \
# 0       ['bidenliesabouttaxes']  ...        NaN      NaN         NaN
# 1                            []  ...        NaN      NaN         NaN
# 2                            []  ...        NaN      NaN         NaN
# 3                            []  ...        NaN      NaN         NaN
# 4                            []  ...        NaN      NaN         NaN
# ...                         ...  ...        ...      ...         ...
# 247830                       []  ...        NaN      NaN         NaN
# 247831                       []  ...        NaN      NaN         NaN
# 247832                       []  ...        NaN      NaN         NaN
# 247833                       []  ...        NaN      NaN         NaN
# 247834                       []  ...        NaN      NaN         NaN
#
#                                                  reply_to retweet_date  \
# 0       [{'screen_name': 'JoeBiden', 'name': 'Joe Bide...          NaN
# 1                                                      []          NaN
# 2       [{'screen_name': 'nashvegas__', 'name': 'Nash'...          NaN
# 3                                                      []          NaN
# 4       [{'screen_name': 'TuckerCarlson', 'name': 'Tuc...          NaN
# ...                                                   ...          ...
# 247830                                                 []          NaN
# 247831                                                 []          NaN
# 247832                                                 []          NaN
# 247833                                                 []          NaN
# 247834  [{'screen_name': 'baxterpm', 'name': 'Paul Bax...          NaN
#
#         translate  trans_src trans_dest     user_fn   user_ln
# 0             NaN        NaN        NaN    Franklin    Emsley
# 1             NaN        NaN        NaN          G.   William
# 2             NaN        NaN        NaN        Adam  Morrison
# 3             NaN        NaN        NaN        Adam  Morrison
# 4             NaN        NaN        NaN        Mary   Bridges
# ...           ...        ...        ...         ...       ...
# 247830        NaN        NaN        NaN      Pirate        in
# 247831        NaN        NaN        NaN      Pirate        in
# 247832        NaN        NaN        NaN      Pirate        in
# 247833        NaN        NaN        NaN      Pirate        in
# 247834        NaN        NaN        NaN  Optimistic   Moondog
#
# [247835 rows x 41 columns]

# %%
df_race = pandas.read_csv('condensed_lastnames.csv', header=None)
df_race.columns = ["last_names", "race/ethnicity"]
df_race
# Out:
#          last_names race/ethnicity
# 0            MILLER          white
# 1            MURPHY          white
# 2              COOK          white
# 3          PETERSON          white
# 4               COX          white
# ...             ...            ...
# 136051  CHILLOGALLO       hispanic
# 136052  CUATIANQUIZ       hispanic
# 136053       DICENT       hispanic
# 136054   DELATEJERA       hispanic
# 136055        EGUES       hispanic
#
# [136056 rows x 2 columns]

# %%
df["user_ln"] = df["user_ln"].str.lower()
df_tweets_ln = df.set_index('user_ln')

df_race["last_names"] = df_race["last_names"].str.lower()
df_race_ln = df_race.set_index('last_names')

df_tweets_ln[['race/ethnicity']] = df_race_ln[['race/ethnicity']]
df_tweets_ln
# Out:
#           Unnamed: 0                   id      conversation_id    created_at  \
# user_ln
# emsley             0  1323308238167822338  1323069815880327173  1.604336e+12
# william            1  1323014312139640833  1323014312139640833  1.604266e+12
# morrison           2  1321831269991407618  1321810507414818821  1.603984e+12
# morrison           3  1321830002590179329  1321830002590179329  1.603984e+12
# bridges            4  1321629643863150592  1321577509704601601  1.603936e+12
# ...              ...                  ...                  ...           ...
# in                23  1285911223037501440  1285911223037501440  1.595420e+12
# in                24  1285910798548770818  1285910798548770818  1.595420e+12
# in                25  1285758027803623424  1285758027803623424  1.595384e+12
# in                26  1285755913706577925  1285755913706577925  1.595383e+12
# moondog           27  1252644543251415041  1250984356023357440  1.587489e+12
#
#                          date  timezone place  \
# user_ln
# emsley    2020-11-02 08:57:24      -800   NaN
# william   2020-11-01 13:29:27      -800   NaN
# morrison  2020-10-29 08:08:27      -800   NaN
# morrison  2020-10-29 08:03:25      -800   NaN
# bridges   2020-10-28 18:47:16      -800   NaN
# ...                       ...       ...   ...
# in        2020-07-22 05:15:01      -800   NaN
# in        2020-07-22 05:13:20      -800   NaN
# in        2020-07-21 19:06:16      -800   NaN
# in        2020-07-21 18:57:52      -800   NaN
# moondog   2020-04-21 10:05:06      -800   NaN
#
#                                                       tweet language  \
# user_ln
# emsley    @JoeBiden So you are not taking back the tax b...       en
# william   Two more days of campaigning ads and covid sca...       en
# morrison  @nashvegas__ Everyone will be paying higher ta...       en
# morrison  I swear this man has been reading my mind for ...       en
# bridges   @TuckerCarlson Joe Biden is not a career polit...       en
# ...                                                     ...      ...
# in        Trump genocide he's killing people all over Am...       en
# in        Trump has killed 140000 people can't change th...       en
# in        No one is trying harder than Kemp to kill peop...       en
# in        They are killing kids at border daily Trump is...       en
# moondog   @baxterpm If it means getting a dig in at trum...       en
#
#                          hashtags  ... user_rt_id  user_rt  retweet_id  \
# user_ln                            ...
# emsley    ['bidenliesabouttaxes']  ...        NaN      NaN         NaN
# william                        []  ...        NaN      NaN         NaN
# morrison                       []  ...        NaN      NaN         NaN
# morrison                       []  ...        NaN      NaN         NaN
# bridges                        []  ...        NaN      NaN         NaN
# ...                           ...  ...        ...      ...         ...
# in                             []  ...        NaN      NaN         NaN
# in                             []  ...        NaN      NaN         NaN
# in                             []  ...        NaN      NaN         NaN
# in                             []  ...        NaN      NaN         NaN
# moondog                        []  ...        NaN      NaN         NaN
#
#                                                    reply_to retweet_date  \
# user_ln
# emsley    [{'screen_name': 'JoeBiden', 'name': 'Joe Bide...          NaN
# william                                                  []          NaN
# morrison  [{'screen_name': 'nashvegas__', 'name': 'Nash'...          NaN
# morrison                                                 []          NaN
# bridges   [{'screen_name': 'TuckerCarlson', 'name': 'Tuc...          NaN
# ...                                                     ...          ...
# in                                                       []          NaN
# in                                                       []          NaN
# in                                                       []          NaN
# in                                                       []          NaN
# moondog   [{'screen_name': 'baxterpm', 'name': 'Paul Bax...          NaN
#
#           translate  trans_src trans_dest     user_fn race/ethnicity
# user_ln
# emsley          NaN        NaN        NaN    Franklin          white
# william         NaN        NaN        NaN          G.            NaN
# morrison        NaN        NaN        NaN        Adam            NaN
# morrison        NaN        NaN        NaN        Adam            NaN
# bridges         NaN        NaN        NaN        Mary            NaN
# ...             ...        ...        ...         ...            ...
# in              NaN        NaN        NaN      Pirate            api
# in              NaN        NaN        NaN      Pirate            api
# in              NaN        NaN        NaN      Pirate            api
# in              NaN        NaN        NaN      Pirate            api
# moondog         NaN        NaN        NaN  Optimistic            NaN
#
# [247835 rows x 41 columns]

# %%
df_with_race = df_tweets_ln.reset_index()
df_with_race
# Out:
#          user_ln  Unnamed: 0                   id      conversation_id  \
# 0         emsley           0  1323308238167822338  1323069815880327173
# 1        william           1  1323014312139640833  1323014312139640833
# 2       morrison           2  1321831269991407618  1321810507414818821
# 3       morrison           3  1321830002590179329  1321830002590179329
# 4        bridges           4  1321629643863150592  1321577509704601601
# ...          ...         ...                  ...                  ...
# 247830        in          23  1285911223037501440  1285911223037501440
# 247831        in          24  1285910798548770818  1285910798548770818
# 247832        in          25  1285758027803623424  1285758027803623424
# 247833        in          26  1285755913706577925  1285755913706577925
# 247834   moondog          27  1252644543251415041  1250984356023357440
#
#           created_at                 date  timezone place  \
# 0       1.604336e+12  2020-11-02 08:57:24      -800   NaN
# 1       1.604266e+12  2020-11-01 13:29:27      -800   NaN
# 2       1.603984e+12  2020-10-29 08:08:27      -800   NaN
# 3       1.603984e+12  2020-10-29 08:03:25      -800   NaN
# 4       1.603936e+12  2020-10-28 18:47:16      -800   NaN
# ...              ...                  ...       ...   ...
# 247830  1.595420e+12  2020-07-22 05:15:01      -800   NaN
# 247831  1.595420e+12  2020-07-22 05:13:20      -800   NaN
# 247832  1.595384e+12  2020-07-21 19:06:16      -800   NaN
# 247833  1.595383e+12  2020-07-21 18:57:52      -800   NaN
# 247834  1.587489e+12  2020-04-21 10:05:06      -800   NaN
#
#                                                     tweet language  ...  \
# 0       @JoeBiden So you are not taking back the tax b...       en  ...
# 1       Two more days of campaigning ads and covid sca...       en  ...
# 2       @nashvegas__ Everyone will be paying higher ta...       en  ...
# 3       I swear this man has been reading my mind for ...       en  ...
# 4       @TuckerCarlson Joe Biden is not a career polit...       en  ...
# ...                                                   ...      ...  ...
# 247830  Trump genocide he's killing people all over Am...       en  ...
# 247831  Trump has killed 140000 people can't change th...       en  ...
# 247832  No one is trying harder than Kemp to kill peop...       en  ...
# 247833  They are killing kids at border daily Trump is...       en  ...
# 247834  @baxterpm If it means getting a dig in at trum...       en  ...
#
#        user_rt_id user_rt  retweet_id  \
# 0             NaN     NaN         NaN
# 1             NaN     NaN         NaN
# 2             NaN     NaN         NaN
# 3             NaN     NaN         NaN
# 4             NaN     NaN         NaN
# ...           ...     ...         ...
# 247830        NaN     NaN         NaN
# 247831        NaN     NaN         NaN
# 247832        NaN     NaN         NaN
# 247833        NaN     NaN         NaN
# 247834        NaN     NaN         NaN
#
#                                                  reply_to retweet_date  \
# 0       [{'screen_name': 'JoeBiden', 'name': 'Joe Bide...          NaN
# 1                                                      []          NaN
# 2       [{'screen_name': 'nashvegas__', 'name': 'Nash'...          NaN
# 3                                                      []          NaN
# 4       [{'screen_name': 'TuckerCarlson', 'name': 'Tuc...          NaN
# ...                                                   ...          ...
# 247830                                                 []          NaN
# 247831                                                 []          NaN
# 247832                                                 []          NaN
# 247833                                                 []          NaN
# 247834  [{'screen_name': 'baxterpm', 'name': 'Paul Bax...          NaN
#
#        translate  trans_src  trans_dest     user_fn race/ethnicity
# 0            NaN        NaN         NaN    Franklin          white
# 1            NaN        NaN         NaN          G.            NaN
# 2            NaN        NaN         NaN        Adam            NaN
# 3            NaN        NaN         NaN        Adam            NaN
# 4            NaN        NaN         NaN        Mary            NaN
# ...          ...        ...         ...         ...            ...
# 247830       NaN        NaN         NaN      Pirate            api
# 247831       NaN        NaN         NaN      Pirate            api
# 247832       NaN        NaN         NaN      Pirate            api
# 247833       NaN        NaN         NaN      Pirate            api
# 247834       NaN        NaN         NaN  Optimistic            NaN
#
# [247835 rows x 42 columns]

# %%
df_with_race.groupby('race/ethnicity').count()
# Out:
#                 user_ln  Unnamed: 0     id  conversation_id  created_at  \
# race/ethnicity
# aian                 35          35     35               35          35
# api                2220        2220   2220             2220        2220
# black               500         500    500              500         500
# hispanic           4552        4552   4552             4552        4552
# white             59322       59330  59330            59330       59330
#
#                  date  timezone  place  tweet  language  ...  source  \
# race/ethnicity                                           ...
# aian               35        35      0     35        35  ...       0
# api              2220      2220     12   2220      2220  ...       0
# black             500       500      3    500       500  ...       0
# hispanic         4552      4552     51   4552      4552  ...       0
# white           59330     59330    531  59330     59330  ...       0
#
#                 user_rt_id  user_rt  retweet_id  reply_to  retweet_date  \
# race/ethnicity
# aian                     0        0           0        35             0
# api                      0        0           0      2220             0
# black                    0        0           0       500             0
# hispanic                 0        0           0      4552             0
# white                    0        0           0     59330             0
#
#                 translate  trans_src  trans_dest  user_fn
# race/ethnicity
# aian                    0          0           0       35
# api                     0          0           0     2220
# black                   0          0           0      500
# hispanic                0          0           0     4552
# white                   0          0           0    59322
#
# [5 rows x 41 columns]

# %%
df_gender = pandas.read_csv('condensed_first_names.csv', header=None)
df_gender.columns = ['firstnames', 'gender', 'count', 'grouped', 'grouped_percent']
df_gender.drop(['count', 'grouped', 'grouped_percent'], axis = 1, inplace = True)
df_gender
# Out:
#       firstnames gender
# 0          James      M
# 1           John      M
# 2         Robert      M
# 3        Michael      M
# 4           Mary      F
# ...          ...    ...
# 90803    Crettie      F
# 90804   Jolieann      F
# 90805     Lonika      F
# 90806     Jolian      M
# 90807      Zzyzx      M
#
# [90808 rows x 2 columns]

# %%
df_with_race["user_fn"] = df_with_race["user_fn"].str.lower()
df_tweets_fn = df_with_race.set_index('user_fn')
display(df_tweets_fn)

df_gender["firstnames"] = df_gender["firstnames"].str.lower()
df_gender_fn = df_gender.set_index('firstnames')
display(df_gender_fn)

df_tweets_fn[['gender']] = df_gender_fn[['gender']]
# Out:
#              user_ln  Unnamed: 0                   id      conversation_id  \
# user_fn
# franklin      emsley           0  1323308238167822338  1323069815880327173
# g.           william           1  1323014312139640833  1323014312139640833
# adam        morrison           2  1321831269991407618  1321810507414818821
# adam        morrison           3  1321830002590179329  1321830002590179329
# mary         bridges           4  1321629643863150592  1321577509704601601
# ...              ...         ...                  ...                  ...
# pirate            in          23  1285911223037501440  1285911223037501440
# pirate            in          24  1285910798548770818  1285910798548770818
# pirate            in          25  1285758027803623424  1285758027803623424
# pirate            in          26  1285755913706577925  1285755913706577925
# optimistic   moondog          27  1252644543251415041  1250984356023357440
#
#               created_at                 date  timezone place  \
# user_fn
# franklin    1.604336e+12  2020-11-02 08:57:24      -800   NaN
# g.          1.604266e+12  2020-11-01 13:29:27      -800   NaN
# adam        1.603984e+12  2020-10-29 08:08:27      -800   NaN
# adam        1.603984e+12  2020-10-29 08:03:25      -800   NaN
# mary        1.603936e+12  2020-10-28 18:47:16      -800   NaN
# ...                  ...                  ...       ...   ...
# pirate      1.595420e+12  2020-07-22 05:15:01      -800   NaN
# pirate      1.595420e+12  2020-07-22 05:13:20      -800   NaN
# pirate      1.595384e+12  2020-07-21 19:06:16      -800   NaN
# pirate      1.595383e+12  2020-07-21 18:57:52      -800   NaN
# optimistic  1.587489e+12  2020-04-21 10:05:06      -800   NaN
#
#                                                         tweet language  ...  \
# user_fn                                                                 ...
# franklin    @JoeBiden So you are not taking back the tax b...       en  ...
# g.          Two more days of campaigning ads and covid sca...       en  ...
# adam        @nashvegas__ Everyone will be paying higher ta...       en  ...
# adam        I swear this man has been reading my mind for ...       en  ...
# mary        @TuckerCarlson Joe Biden is not a career polit...       en  ...
# ...                                                       ...      ...  ...
# pirate      Trump genocide he's killing people all over Am...       en  ...
# pirate      Trump has killed 140000 people can't change th...       en  ...
# pirate      No one is trying harder than Kemp to kill peop...       en  ...
# pirate      They are killing kids at border daily Trump is...       en  ...
# optimistic  @baxterpm If it means getting a dig in at trum...       en  ...
#
#            source user_rt_id  user_rt  retweet_id  \
# user_fn
# franklin      NaN        NaN      NaN         NaN
# g.            NaN        NaN      NaN         NaN
# adam          NaN        NaN      NaN         NaN
# adam          NaN        NaN      NaN         NaN
# mary          NaN        NaN      NaN         NaN
# ...           ...        ...      ...         ...
# pirate        NaN        NaN      NaN         NaN
# pirate        NaN        NaN      NaN         NaN
# pirate        NaN        NaN      NaN         NaN
# pirate        NaN        NaN      NaN         NaN
# optimistic    NaN        NaN      NaN         NaN
#
#                                                      reply_to retweet_date  \
# user_fn
# franklin    [{'screen_name': 'JoeBiden', 'name': 'Joe Bide...          NaN
# g.                                                         []          NaN
# adam        [{'screen_name': 'nashvegas__', 'name': 'Nash'...          NaN
# adam                                                       []          NaN
# mary        [{'screen_name': 'TuckerCarlson', 'name': 'Tuc...          NaN
# ...                                                       ...          ...
# pirate                                                     []          NaN
# pirate                                                     []          NaN
# pirate                                                     []          NaN
# pirate                                                     []          NaN
# optimistic  [{'screen_name': 'baxterpm', 'name': 'Paul Bax...          NaN
#
#             translate  trans_src trans_dest race/ethnicity
# user_fn
# franklin          NaN        NaN        NaN          white
# g.                NaN        NaN        NaN            NaN
# adam              NaN        NaN        NaN            NaN
# adam              NaN        NaN        NaN            NaN
# mary              NaN        NaN        NaN            NaN
# ...               ...        ...        ...            ...
# pirate            NaN        NaN        NaN            api
# pirate            NaN        NaN        NaN            api
# pirate            NaN        NaN        NaN            api
# pirate            NaN        NaN        NaN            api
# optimistic        NaN        NaN        NaN            NaN
#
# [247835 rows x 41 columns]
#            gender
# firstnames
# james           M
# john            M
# robert          M
# michael         M
# mary            F
# ...           ...
# crettie         F
# jolieann        F
# lonika          F
# jolian          M
# zzyzx           M
#
# [90808 rows x 1 columns]

# %%
df_tweets_fn
# Out:
#              user_ln  Unnamed: 0                   id      conversation_id  \
# user_fn
# franklin      emsley           0  1323308238167822338  1323069815880327173
# g.           william           1  1323014312139640833  1323014312139640833
# adam        morrison           2  1321831269991407618  1321810507414818821
# adam        morrison           3  1321830002590179329  1321830002590179329
# mary         bridges           4  1321629643863150592  1321577509704601601
# ...              ...         ...                  ...                  ...
# pirate            in          23  1285911223037501440  1285911223037501440
# pirate            in          24  1285910798548770818  1285910798548770818
# pirate            in          25  1285758027803623424  1285758027803623424
# pirate            in          26  1285755913706577925  1285755913706577925
# optimistic   moondog          27  1252644543251415041  1250984356023357440
#
#               created_at                 date  timezone place  \
# user_fn
# franklin    1.604336e+12  2020-11-02 08:57:24      -800   NaN
# g.          1.604266e+12  2020-11-01 13:29:27      -800   NaN
# adam        1.603984e+12  2020-10-29 08:08:27      -800   NaN
# adam        1.603984e+12  2020-10-29 08:03:25      -800   NaN
# mary        1.603936e+12  2020-10-28 18:47:16      -800   NaN
# ...                  ...                  ...       ...   ...
# pirate      1.595420e+12  2020-07-22 05:15:01      -800   NaN
# pirate      1.595420e+12  2020-07-22 05:13:20      -800   NaN
# pirate      1.595384e+12  2020-07-21 19:06:16      -800   NaN
# pirate      1.595383e+12  2020-07-21 18:57:52      -800   NaN
# optimistic  1.587489e+12  2020-04-21 10:05:06      -800   NaN
#
#                                                         tweet language  ...  \
# user_fn                                                                 ...
# franklin    @JoeBiden So you are not taking back the tax b...       en  ...
# g.          Two more days of campaigning ads and covid sca...       en  ...
# adam        @nashvegas__ Everyone will be paying higher ta...       en  ...
# adam        I swear this man has been reading my mind for ...       en  ...
# mary        @TuckerCarlson Joe Biden is not a career polit...       en  ...
# ...                                                       ...      ...  ...
# pirate      Trump genocide he's killing people all over Am...       en  ...
# pirate      Trump has killed 140000 people can't change th...       en  ...
# pirate      No one is trying harder than Kemp to kill peop...       en  ...
# pirate      They are killing kids at border daily Trump is...       en  ...
# optimistic  @baxterpm If it means getting a dig in at trum...       en  ...
#
#            user_rt_id user_rt  retweet_id  \
# user_fn
# franklin          NaN     NaN         NaN
# g.                NaN     NaN         NaN
# adam              NaN     NaN         NaN
# adam              NaN     NaN         NaN
# mary              NaN     NaN         NaN
# ...               ...     ...         ...
# pirate            NaN     NaN         NaN
# pirate            NaN     NaN         NaN
# pirate            NaN     NaN         NaN
# pirate            NaN     NaN         NaN
# optimistic        NaN     NaN         NaN
#
#                                                      reply_to retweet_date  \
# user_fn
# franklin    [{'screen_name': 'JoeBiden', 'name': 'Joe Bide...          NaN
# g.                                                         []          NaN
# adam        [{'screen_name': 'nashvegas__', 'name': 'Nash'...          NaN
# adam                                                       []          NaN
# mary        [{'screen_name': 'TuckerCarlson', 'name': 'Tuc...          NaN
# ...                                                       ...          ...
# pirate                                                     []          NaN
# pirate                                                     []          NaN
# pirate                                                     []          NaN
# pirate                                                     []          NaN
# optimistic  [{'screen_name': 'baxterpm', 'name': 'Paul Bax...          NaN
#
#            translate  trans_src  trans_dest race/ethnicity gender
# user_fn
# franklin         NaN        NaN         NaN          white      M
# g.               NaN        NaN         NaN            NaN    NaN
# adam             NaN        NaN         NaN            NaN      M
# adam             NaN        NaN         NaN            NaN      M
# mary             NaN        NaN         NaN            NaN      F
# ...              ...        ...         ...            ...    ...
# pirate           NaN        NaN         NaN            api    NaN
# pirate           NaN        NaN         NaN            api    NaN
# pirate           NaN        NaN         NaN            api    NaN
# pirate           NaN        NaN         NaN            api    NaN
# optimistic       NaN        NaN         NaN            NaN    NaN
#
# [247835 rows x 42 columns]

# %%
df_race_and_gender = df_tweets_fn.reset_index()

# %%
df_race_and_gender
# Out:
#            user_fn   user_ln  Unnamed: 0                   id  \
# 0         franklin    emsley           0  1323308238167822338
# 1               g.   william           1  1323014312139640833
# 2             adam  morrison           2  1321831269991407618
# 3             adam  morrison           3  1321830002590179329
# 4             mary   bridges           4  1321629643863150592
# ...            ...       ...         ...                  ...
# 247830      pirate        in          23  1285911223037501440
# 247831      pirate        in          24  1285910798548770818
# 247832      pirate        in          25  1285758027803623424
# 247833      pirate        in          26  1285755913706577925
# 247834  optimistic   moondog          27  1252644543251415041
#
#             conversation_id    created_at                 date  timezone  \
# 0       1323069815880327173  1.604336e+12  2020-11-02 08:57:24      -800
# 1       1323014312139640833  1.604266e+12  2020-11-01 13:29:27      -800
# 2       1321810507414818821  1.603984e+12  2020-10-29 08:08:27      -800
# 3       1321830002590179329  1.603984e+12  2020-10-29 08:03:25      -800
# 4       1321577509704601601  1.603936e+12  2020-10-28 18:47:16      -800
# ...                     ...           ...                  ...       ...
# 247830  1285911223037501440  1.595420e+12  2020-07-22 05:15:01      -800
# 247831  1285910798548770818  1.595420e+12  2020-07-22 05:13:20      -800
# 247832  1285758027803623424  1.595384e+12  2020-07-21 19:06:16      -800
# 247833  1285755913706577925  1.595383e+12  2020-07-21 18:57:52      -800
# 247834  1250984356023357440  1.587489e+12  2020-04-21 10:05:06      -800
#
#        place                                              tweet  ...  \
# 0        NaN  @JoeBiden So you are not taking back the tax b...  ...
# 1        NaN  Two more days of campaigning ads and covid sca...  ...
# 2        NaN  @nashvegas__ Everyone will be paying higher ta...  ...
# 3        NaN  I swear this man has been reading my mind for ...  ...
# 4        NaN  @TuckerCarlson Joe Biden is not a career polit...  ...
# ...      ...                                                ...  ...
# 247830   NaN  Trump genocide he's killing people all over Am...  ...
# 247831   NaN  Trump has killed 140000 people can't change th...  ...
# 247832   NaN  No one is trying harder than Kemp to kill peop...  ...
# 247833   NaN  They are killing kids at border daily Trump is...  ...
# 247834   NaN  @baxterpm If it means getting a dig in at trum...  ...
#
#        user_rt_id user_rt retweet_id  \
# 0             NaN     NaN        NaN
# 1             NaN     NaN        NaN
# 2             NaN     NaN        NaN
# 3             NaN     NaN        NaN
# 4             NaN     NaN        NaN
# ...           ...     ...        ...
# 247830        NaN     NaN        NaN
# 247831        NaN     NaN        NaN
# 247832        NaN     NaN        NaN
# 247833        NaN     NaN        NaN
# 247834        NaN     NaN        NaN
#
#                                                  reply_to  retweet_date  \
# 0       [{'screen_name': 'JoeBiden', 'name': 'Joe Bide...           NaN
# 1                                                      []           NaN
# 2       [{'screen_name': 'nashvegas__', 'name': 'Nash'...           NaN
# 3                                                      []           NaN
# 4       [{'screen_name': 'TuckerCarlson', 'name': 'Tuc...           NaN
# ...                                                   ...           ...
# 247830                                                 []           NaN
# 247831                                                 []           NaN
# 247832                                                 []           NaN
# 247833                                                 []           NaN
# 247834  [{'screen_name': 'baxterpm', 'name': 'Paul Bax...           NaN
#
#        translate trans_src  trans_dest  race/ethnicity gender
# 0            NaN       NaN         NaN           white      M
# 1            NaN       NaN         NaN             NaN    NaN
# 2            NaN       NaN         NaN             NaN      M
# 3            NaN       NaN         NaN             NaN      M
# 4            NaN       NaN         NaN             NaN      F
# ...          ...       ...         ...             ...    ...
# 247830       NaN       NaN         NaN             api    NaN
# 247831       NaN       NaN         NaN             api    NaN
# 247832       NaN       NaN         NaN             api    NaN
# 247833       NaN       NaN         NaN             api    NaN
# 247834       NaN       NaN         NaN             NaN    NaN
#
# [247835 rows x 43 columns]

# %%
df_race_and_gender.drop(['urls', 'photos', 'video', 'thumbnail'], axis = 1, inplace = True)
df_race_and_gender
# Out:
#                        date place  \
# 0       2020-11-02 08:57:24   NaN
# 1       2020-11-01 13:29:27   NaN
# 2       2020-10-29 08:08:27   NaN
# 3       2020-10-29 08:03:25   NaN
# 4       2020-10-28 18:47:16   NaN
# ...                     ...   ...
# 247830  2020-07-22 05:15:01   NaN
# 247831  2020-07-22 05:13:20   NaN
# 247832  2020-07-21 19:06:16   NaN
# 247833  2020-07-21 18:57:52   NaN
# 247834  2020-04-21 10:05:06   NaN
#
#                                                     tweet language  \
# 0       @JoeBiden So you are not taking back the tax b...       en
# 1       Two more days of campaigning ads and covid sca...       en
# 2       @nashvegas__ Everyone will be paying higher ta...       en
# 3       I swear this man has been reading my mind for ...       en
# 4       @TuckerCarlson Joe Biden is not a career polit...       en
# ...                                                   ...      ...
# 247830  Trump genocide he's killing people all over Am...       en
# 247831  Trump has killed 140000 people can't change th...       en
# 247832  No one is trying harder than Kemp to kill peop...       en
# 247833  They are killing kids at border daily Trump is...       en
# 247834  @baxterpm If it means getting a dig in at trum...       en
#
#                        hashtags         username                  name  \
# 0       ['bidenliesabouttaxes']      frankemsley       Franklin Emsley
# 1                            []       Gknott1970      G. William Knott
# 2                            []          wAdam_M         Adam Morrison
# 3                            []          wAdam_M         Adam Morrison
# 4                            []     MaryBriBri61          Mary Bridges
# ...                         ...              ...                   ...
# 247830                       []  keffberrystrien  Pirate in the desert
# 247831                       []  keffberrystrien  Pirate in the desert
# 247832                       []  keffberrystrien  Pirate in the desert
# 247833                       []  keffberrystrien  Pirate in the desert
# 247834                       []  thelonewolffft2    Optimistic Moondog
#
#                                                      link  retweet  \
# 0       https://twitter.com/frankemsley/status/1323308...    False
# 1       https://twitter.com/Gknott1970/status/13230143...    False
# 2       https://twitter.com/wAdam_M/status/13218312699...    False
# 3       https://twitter.com/wAdam_M/status/13218300025...    False
# 4       https://twitter.com/MaryBriBri61/status/132162...    False
# ...                                                   ...      ...
# 247830  https://twitter.com/keffberrystrien/status/128...    False
# 247831  https://twitter.com/keffberrystrien/status/128...    False
# 247832  https://twitter.com/keffberrystrien/status/128...    False
# 247833  https://twitter.com/keffberrystrien/status/128...    False
# 247834  https://twitter.com/thelonewolffft2/status/125...    False
#
#                 search                  near  \
# 0       trump OR biden  Albertville, Alabama
# 1       trump OR biden  Albertville, Alabama
# 2       trump OR biden  Albertville, Alabama
# 3       trump OR biden  Albertville, Alabama
# 4       trump OR biden  Albertville, Alabama
# ...                ...                   ...
# 247830  trump OR biden      Buffalo, Wyoming
# 247831  trump OR biden      Buffalo, Wyoming
# 247832  trump OR biden      Buffalo, Wyoming
# 247833  trump OR biden      Buffalo, Wyoming
# 247834  trump OR biden      Buffalo, Wyoming
#
#                                                  reply_to race/ethnicity  \
# 0       [{'screen_name': 'JoeBiden', 'name': 'Joe Bide...          white
# 1                                                      []            NaN
# 2       [{'screen_name': 'nashvegas__', 'name': 'Nash'...            NaN
# 3                                                      []            NaN
# 4       [{'screen_name': 'TuckerCarlson', 'name': 'Tuc...            NaN
# ...                                                   ...            ...
# 247830                                                 []            api
# 247831                                                 []            api
# 247832                                                 []            api
# 247833                                                 []            api
# 247834  [{'screen_name': 'baxterpm', 'name': 'Paul Bax...            NaN
#
#        gender
# 0           M
# 1         NaN
# 2           M
# 3           M
# 4           F
# ...       ...
# 247830    NaN
# 247831    NaN
# 247832    NaN
# 247833    NaN
# 247834    NaN
#
# [247835 rows x 14 columns]

# %%
df_race_and_gender.groupby('race/ethnicity').count()
# Out:
#                  date  place  tweet  language  hashtags  username   name  \
# race/ethnicity
# aian               35      0     35        35        35        35     35
# api              2220     12   2220      2220      2220      2220   2220
# black             500      3    500       500       500       500    500
# hispanic         4552     51   4552      4552      4552      4552   4552
# white           59330    531  59330     59330     59330     59330  59322
#
#                  link  retweet  search   near  reply_to  gender
# race/ethnicity
# aian               35       35      35     35        35      13
# api              2220     2220    2220   2220      2220    1170
# black             500      500     500    500       500     391
# hispanic         4552     4552    4552   4552      4552    4200
# white           59330    59330   59330  59330     59330   51970

# %%
df_race_and_gender.groupby('gender').count()
# Out:
#          date  place  tweet  language  hashtags  username   name   link  \
# gender
# F       60772    443  60772     60772     60772     60772  60772  60772
# M       99140    952  99140     99140     99140     99140  99140  99140
#
#         retweet  search   near  reply_to  race/ethnicity
# gender
# F         60772   60772  60772     60772           20531
# M         99140   99140  99140     99140           37213

# %%
import csv
df_race_and_gender.to_csv('race&gender-2020-all.csv',quoting=csv.QUOTE_ALL)
